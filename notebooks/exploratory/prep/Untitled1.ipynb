# %%
import os 
os.chdir("/home/rocassius/w266_final/scripts/assembly")

# %%
#========================#
#=*= Making Documents =*=#
#========================#

# makes and saves document dataframes

import time
import pandas as pd

from multiprocessing import cpu_count, Process, Pool
from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import ProcessPoolExecutor 
from functools import partial
    
from constant import GEN_HB_PATH_2, MIN_SESSION, MAX_SESSION
from subject import subject_keywords
from document import *


# constants
N_CORES = cpu_count()
SAVE_PATH = "/home/rocassius/gen-data/doc/doc-all"
sessions = list(range(MIN_SESSION, MAX_SESSION+1))

WINDOW_TOKENS = 75

def main():
    
    # time it
    start = time.time()
    
    document_maker = partial(
        save_session_documents,
        subjects=subject_keywords.keys(), 
        speech_path=GEN_HB_PATH_2, 
        write_path=SAVE_PATH,  
        window_tokens=WINDOW_TOKENS)
    
    # execute in parallel
    with ThreadPoolExecutor(max_workers = 5 * N_CORES) as executor:
        executor.map(document_maker, sessions)  

    end = time.time()
    elapsed = end - start

    # report
    print("SUCCESS, took", round(elapsed / 60, 2), "minutes")
     
        
if __name__ == "__main__":
    main()
# Out:
# DOCUMENTS MADE for session 57
# DOCUMENTS MADE for session 54
# DOCUMENTS MADE for session 44
# DOCUMENTS MADE for session 60
# DOCUMENTS MADE for session 58
# DOCUMENTS MADE for session 48
# DOCUMENTS MADE for session 43
# DOCUMENTS MADE for session 45
# DOCUMENTS MADE for session 52
# DOCUMENTS MADE for session 56
# DOCUMENTS MADE for session 46
# DOCUMENTS MADE for session 70
# DOCUMENTS MADE for session 59
# DOCUMENTS MADE for session 50
# DOCUMENTS MADE for session 49
# DOCUMENTS MADE for session 68
# DOCUMENTS MADE for session 69
# DOCUMENTS MADE for session 55
# DOCUMENTS MADE for session 73
# DOCUMENTS MADE for session 47
# DOCUMENTS MADE for session 75
# DOCUMENTS MADE for session 53
# DOCUMENTS MADE for session 77
# DOCUMENTS MADE for session 61
# DOCUMENTS MADE for session 64
# DOCUMENTS MADE for session 72
# DOCUMENTS MADE for session 51
# DOCUMENTS MADE for session 74
# DOCUMENTS MADE for session 62
# DOCUMENTS MADE for session 80
# DOCUMENTS MADE for session 78
# DOCUMENTS MADE for session 82
# DOCUMENTS MADE for session 71
# DOCUMENTS MADE for session 76
# DOCUMENTS MADE for session 79
# DOCUMENTS MADE for session 66
# DOCUMENTS MADE for session 65
# DOCUMENTS MADE for session 83
# DOCUMENTS MADE for session 84
# DOCUMENTS MADE for session 81
# DOCUMENTS MADE for session 67
# DOCUMENTS MADE for session 63
# DOCUMENTS MADE for session 86
# DOCUMENTS MADE for session 111
# DOCUMENTS MADE for session 107
# DOCUMENTS MADE for session 85
# DOCUMENTS MADE for session 109
# DOCUMENTS MADE for session 110
# DOCUMENTS MADE for session 108
# DOCUMENTS MADE for session 105
# DOCUMENTS MADE for session 97
# DOCUMENTS MADE for session 87
# DOCUMENTS MADE for session 88
# DOCUMENTS MADE for session 106
# DOCUMENTS MADE for session 90
# DOCUMENTS MADE for session 101
# DOCUMENTS MADE for session 98
# DOCUMENTS MADE for session 103
# DOCUMENTS MADE for session 100
# DOCUMENTS MADE for session 96
# DOCUMENTS MADE for session 92
# DOCUMENTS MADE for session 102
# DOCUMENTS MADE for session 89
# DOCUMENTS MADE for session 99
# DOCUMENTS MADE for session 94
# DOCUMENTS MADE for session 104
# DOCUMENTS MADE for session 95
# DOCUMENTS MADE for session 91
# DOCUMENTS MADE for session 93
# SUCCESS, took 82.25 minutes
