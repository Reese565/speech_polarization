# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd
from distributed import Client

import gensim
import os

os.chdir("../../scripts/assembly")
from session_speaker_assembly_dd import *

# %%
# 111th session Example
s = 111
speaker_map, session_phrases = session_phrases_dd(session=111)

# %%
valid_phrases = select_phrase_classes_dd(session_phrase_dd=session_phrases, classes=['vocab'])

# %%
speaker_docs = speaker_docs_dd(valid_phrases)
# Out:
# /home/rocassius/anaconda3/lib/python3.7/site-packages/dask/dataframe/core.py:3981: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta=(None, 'object'))
#
#   warnings.warn(meta_warning(meta))

# %%
speaker_docs.repartition(npartitions=10)
# Out:
# Dask Series Structure:
# npartitions=10
#     object
#        ...
#      ...
#        ...
#        ...
# Name: phrase, dtype: object
# Dask Name: repartition, 128 tasks

# %%
# from distributed import Client, LocalCluster
# cluster = LocalCluster(n_workers=4, 
#                        processes=False, 
#                        scheduler_port=0, 
#                        threads_per_worker=4
#                       )
# c = Client(cluster)
# cluster

# %%
# valid_phrases.visualize()

# %%
# speaker_docs.visualize()

# %%
# this really helped some other people 
pd.options.mode.chained_assignment = None 
# https://github.com/dask/distributed/issues/1467
# something about how pandas reading from csvs wasn't releasing the GIL

# %%
import time


start = time.time()

speaker_docs_df = speaker_docs.compute()

end = time.time()
elapsed = end - start
# Out:
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/51 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/52 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/53 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/54 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/55 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/56 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.56 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.56 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.56 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.57 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/57 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/58 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.67 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.69 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.69 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/59 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.75 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/60 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.79 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/61 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.79 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.79 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.79 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.82 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.91 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.91 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.91 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.83 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.83 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.84 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/62 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.86 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.87 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.87 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.87 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.88 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.88 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.90 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.90 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.92 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.93 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.93 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.93 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/63 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.94 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.95 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.97 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.97 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.98 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.98 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/64 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.00 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.00 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.00 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.00 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.01 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.01 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.04 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.04 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.04 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.04 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.07 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.07 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.07 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.08 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.09 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.11 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.11 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.12 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.12 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.16 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.16 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.17 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/65 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/66 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.17 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.17 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.17 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.17 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.20 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.20 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.21 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.21 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/67 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/68 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.25 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.26 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.26 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.26 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/69 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/70 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.27 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.27 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.27 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.27 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.30 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.31 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.31 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.31 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - gc.collect() took 1.008s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.35 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.35 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - gc.collect() took 1.013s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.35 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - gc.collect() took 1.012s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.36 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.36 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.36 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - gc.collect() took 1.029s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.37 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - gc.collect() took 1.019s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.37 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.37 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.37 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.37 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.38 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - gc.collect() took 1.021s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.39 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.39 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - gc.collect() took 1.027s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 6.40 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.40 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.42 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.43 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.43 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - gc.collect() took 1.068s. This is usually a sign that some tasks handle too many Python objects at the same time. Rechunking the work into smaller tasks might help.
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.43 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/71 remote=inproc://10.168.0.2/8783/1>
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/72 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.45 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.45 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.45 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.46 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.48 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.49 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.49 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.49 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.49 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.50 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.50 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.50 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.54 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.54 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.54 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.54 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.54 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.55 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.55 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.55 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.58 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.58 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.58 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.58 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.58 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.59 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.59 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.59 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.60 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.60 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.60 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.60 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/73 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.60 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.61 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.61 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.61 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.62 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/74 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.65 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.65 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.65 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.69 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.69 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.69 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.69 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.72 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.73 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.73 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/75 remote=inproc://10.168.0.2/8783/17>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.73 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.67 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/76 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.65 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.65 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.65 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.65 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.41 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.30 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/78 remote=inproc://10.168.0.2/8783/17>
# distributed.worker - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/77 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.32 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/79 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Worker is at 78% memory usage. Resuming worker. Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/80 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.24 GB -- Worker memory limit: 7.90 GB
# distributed.comm.inproc - WARNING - Closing dangling queue in <InProc  local=inproc://10.168.0.2/8783/81 remote=inproc://10.168.0.2/8783/1>
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.22 GB -- Worker memory limit: 7.90 GB
# ...
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.77 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.63 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.64 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.65 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.67 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.67 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.67 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.67 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.70 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.70 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.70 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.70 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.70 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.70 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.70 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.78 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.66 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.66 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.66 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.66 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.68 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.71 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.74 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.81 GB -- Worker memory limit: 7.90 GB

# %%
# I think this is pretty good:
# 1st try: compute(), defaults = 11 minutes
# 3nd try: made a client = 13 minutes
# 4th try, 14 minutes

print("Done in " + str(round(elapsed / 60, 2)) + " minutes" )
# Out:
# Done in 14.66 minutes

# %%
c.call_stack()

# %%
speaker_docs.npartitions

# %%
valid_phrases.repartition(npartitions=10)

# %%
multiprocessing.cpu_count()
