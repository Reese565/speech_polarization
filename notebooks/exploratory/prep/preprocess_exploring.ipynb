# %%
import numpy as np
import pandas as pd
from scipy import stats
import os

# %%
os.chdir("/home/rocassius/w266_final/scripts/assembly")
# from session_speaker_assembly import *
# from preprocess import 
#from document import *
from constant import *

# %%
# improt voteview data for congressional memeber names
voteview = pd.read_csv(os.path.join(DATA_PATH, "voteview/congress_ideology.csv"))
voteview['bioname'].head(n=4)
# Out:
# 0      WASHINGTON, George
# 1    HUNTINGTON, Benjamin
# 2          SHERMAN, Roger
# 3       STURGES, Jonathan
# Name: bioname, dtype: object

# %%
# import speeches
speeches = pd.read_csv(os.path.join(HB_PATH, SPEECHES % '111'), sep = "|")

# import vocab master list
phrases_classes = pd.read_csv(os.path.join(DATA_PATH, "vocabulary/master_list.txt"), sep = "|")

# %%
# improt voteview data for congressional memeber names
voteview = pd.read_csv(os.path.join(DATA_PATH, "voteview/congress_ideology.csv"))
voteview['bioname'].head(n=4)
# Out:
# 0      WASHINGTON, George
# 1    HUNTINGTON, Benjamin
# 2          SHERMAN, Roger
# 3       STURGES, Jonathan
# Name: bioname, dtype: object

# %%
speeches.itertuples()

# %%
voteview.columns

# %%
names = voteview[voteview['congress'] >= 43]['bioname'].tolist()
len(names)
names
# Out:
# ['GRANT, Hiram Ulysses',
#  'BROMBERG, Frederick George',
#  'CALDWELL, John Henry',
#  'HAYS, Charles',
#  'PELHAM, Charles',
#  'RAPIER, James Thomas',
#  'SHEATS, Charles Christopher',
#  'SLOSS, Joseph Humphrey',
#  'WHITE, Alexander',
#  'GUNTER, Thomas Montague',
#  'HODGES, Asa',
#  'HYNES, William Joseph',
#  'SNYDER, Oliver P.',
#  'WILSHIRE, William Wallace',
#  'CLAYTON, Charles',
#  'HOUGHTON, Sherman Otis',
#  'LUTTRELL, John King',
#  'PAGE, Horace Francis',
#  'BARNUM, William Henry',
#  'HAWLEY, Joseph Roswell',
#  'KELLOGG, Stephen Wright',
#  'STARKWEATHER, Henry Howard',
#  'LOFLAND, James Rush',
#  'PURMAN, William James',
#  'WALLS, Josiah Thomas',
#  'BELL, Hiram Parks',
#  'BLOUNT, James Henderson',
#  'COOK, Philip',
#  'FREEMAN, James Crawford',
#  'HARRIS, Henry Richard',
#  'RAWLS, Morgan',
#  'SLOAN, Andrew',
#  'STEPHENS, Alexander Hamilton',
#  'WHITELEY, Richard Henry',
#  'YOUNG, Pierce Manning Butler',
#  'BARRERE, Granville',
# ...

# %%
import re
names = sum([re.sub("(\w+)(?=[.!?]).", "", name).split() for name in names], [])
names
# Out:
# ['GRANT,',
#  'Hiram',
#  'Ulysses',
#  'BROMBERG,',
#  'Frederick',
#  'George',
#  'CALDWELL,',
#  'John',
#  'Henry',
#  'HAYS,',
#  'Charles',
#  'PELHAM,',
#  'Charles',
#  'RAPIER,',
#  'James',
#  'Thomas',
#  'SHEATS,',
#  'Charles',
#  'Christopher',
#  'SLOSS,',
#  'Joseph',
#  'Humphrey',
#  'WHITE,',
#  'Alexander',
#  'GUNTER,',
#  'Thomas',
#  'Montague',
#  'HODGES,',
#  'Asa',
#  'HYNES,',
#  'William',
#  'Joseph',
#  'SNYDER,',
#  'Oliver',
#  'WILSHIRE,',
#  'William',
#  'Wallace',
#  'CLAYTON,',
#  'Charles',
#  'HOUGHTON,',
#  'Sherman',
#  'Otis',
#  'LUTTRELL,',
#  'John',
#  'King',
#  'PAGE,',
#  'Horace',
#  'Francis',
#  'BARNUM,',
#  'William',
#  'Henry',
#  'HAWLEY,',
#  'Joseph',
#  'Roswell',
#  'KELLOGG,',
#  'Stephen',
#  'Wright',
#  'STARKWEATHER,',
#  'Henry',
#  'Howard',
#  'LOFLAND,',
#  'James',
#  'Rush',
#  'PURMAN,',
#  'William',
#  'James',
#  'WALLS,',
#  'Josiah',
#  'Thomas',
#  'BELL,',
#  'Hiram',
#  'Parks',
#  'BLOUNT,',
# ...

# %%
len(names)
# Out:
# 109491

# %%
presidents = pd.read_csv("https://gist.githubusercontent.com/namuol/2657233/raw/74135b2637e624848c163759be9cd14ae33f5153/presidents.csv")

# %%
presidents_names = presidents['President '].tolist()
presidents_names[23] = 'Grover Cleveland'
presidents_names
# Out:
# ['George Washington',
#  'John Adams',
#  'Thomas Jefferson',
#  'James Madison',
#  'James Monroe',
#  'John Quincy Adams',
#  'Andrew Jackson',
#  'Martin Van Buren',
#  'William Henry Harrison',
#  'John Tyler',
#  'James K. Polk',
#  'Zachary Taylor',
#  'Millard Fillmore',
#  'Franklin Pierce',
#  'James Buchanan',
#  'Abraham Lincoln',
#  'Andrew Johnson',
#  'Ulysses S. Grant',
#  'Rutherford B. Hayes',
#  'James A. Garfield',
#  'Chester A. Arthur',
#  'Grover Cleveland',
#  'Benjamin Harrison',
#  'Grover Cleveland',
#  'William McKinley',
#  'Theodore Roosevelt',
#  'William Howard Taft',
#  'Woodrow Wilson',
#  'Warren G. Harding',
#  'Calvin Coolidge',
#  'Herbert Hoover',
#  'Franklin D. Roosevelt',
#  'Harry S. Truman',
#  'Dwight D. Eisenhower',
#  'John F. Kennedy',
#  'Lyndon B. Johnson',
#  'Richard Nixon',
#  'Gerald Ford',
#  'Jimmy Carter',
#  'Ronald Reagan',
#  'George H. W. Bush',
#  'Bill Clinton',
#  'George W. Bush',
#  'Barack Obama']

# %%
import re
presidents_names = sum([re.sub("(\w+)(?=[.!?]).", "", name).lower().split() for name in presidents_names], [])

# %%
all_names = names + presidents_names
len(all_names)
# Out:
# 109583

# %%
all_names

# %%
NON_LOWER_ALPHA = "[^a-z\s]"

# %%
from subject import subject_keywords
keywords = sum(subject_keywords.values(),[])

# %%
np.argwhere(np.unique(all_names) == 'nan')
# Out:
# array([], shape=(0, 1), dtype=int64)

# %%
unique_lowered_names = [n.lower() for n in np.unique(all_names)]
unique_lowered_names
# Out:
# ['(',
#  '()',
#  '(abe)',
#  '(abram)',
#  '(alex)',
#  '(andy)',
#  '(ben)',
#  '(bill)',
#  '(bill),',
#  '(billy)',
#  '(bo)',
#  '(bob)',
#  '(bob),',
#  '(brock)',
#  '(buck)',
#  '(bud)',
#  '(bud),',
#  '(buddy)',
#  '(buddy),',
#  '(butch)',
#  '(champ)',
#  '(chan)',
#  '(chet)',
#  '(chip),',
#  '(chuck)',
#  '(clift)',
#  '(curt)',
#  '(cyclone)',
#  '(dan)',
#  '(deb)',
#  '(denny)',
#  '(dick)',
#  '(dina)',
#  '(dixie)',
#  '(doc)',
#  '(don)',
#  '(doug)',
#  '(duke)',
#  '(dutch)',
#  '(ed)',
#  '(frank)',
#  '(gene)',
#  '(geoff)',
#  '(gerry)',
#  '(ginny)',
#  '(gus)',
#  '(gwen)',
#  '(hal)',
#  '(hank)',
#  '(happy)',
#  '(harry)',
#  '(heidi)',
#  '(ike)',
#  '(jack)',
#  '(jackie)',
#  '(jake)',
#  '(james)',
#  '(jay)',
#  '(jeff)',
#  '(jerry)',
#  '(jim)',
#  '(jo)',
#  '(joe)',
#  '(joseph)',
#  '(judge)',
#  '(kathy)',
#  '(kay)',
#  '(kika)',
#  '(kit)',
#  '(lafe)',
#  '(larry)',
#  '(lauch)',
#  '(len)',
#  '(lex)',
#  '(lindy)',
#  '(mac)',
# ...

# %%
for name in unique_lowered_names:
  
    name = re.sub(NON_LOWER_ALPHA, "", name)
    
    if name == 'allott':
        print("HERE")
# Out:
# HERE

# %%
# Out:
# False

# %%
all([type(n) is str for n in np.unique(all_names)])
# Out:
# False

# %%
all([type(n) is str for n in unique_lowered_names])
# Out:
# True

# %%
good_names = []

for name in unique_lowered_names:
    og_name = name
    name = name.lower()
    name = str(re.sub(NON_LOWER_ALPHA, "", name))
    
    if (name not in keywords) and (len(name) > 0) and (type(name) is str) and (name != 'nan'):
        good_names.append(name)
    else:
        print("removing ", og_name)
        
# good_names
# Out:
# removing  (
# removing  ()
# removing  )
# removing  ,
# removing  christian
# removing  forest,
# removing  forest
# removing  gold
# removing  job
# removing  nan

# %%
'nan' in good_names
# Out:
# True

# %%
len(good_names)
# Out:
# 7916

# %%
re.sub(NON_LOWER_ALPHA, "", 'Nan'.lower()) == 'nan'
# Out:
# True

# %%
name = re.sub(NON_LOWER_ALPHA, "", 'Nan'.lower())

if name not in keywords and len(name) > 0 and type(name) is 'str' and name is not 'nan':
    good_names.append(name)
else:
    print("removing ", og_name)
# Out:
# removing  zachary

# %%
np.unique(all_names)[5410:5425]
# Out:
# array(['NORWOOD,', 'NOWAK,', 'NUGENT,', 'NUNES,', 'NUNN,', 'NUNNELEE,',
#        'NUSSLE,', 'NUTE,', 'NUTTING,', 'NUYS,', 'NYE,', 'NYGAARD,',
#        'Nall', 'Nan', 'Nance'], dtype='<U20')

# %%
good_names[5414]
good_names[5410:5420]
# Out:
# ['nuys',
#  'nye',
#  'nygaard',
#  'nall',
#  'nan',
#  'nance',
#  'nancy',
#  'nanette',
#  'napoleon',
#  'nash']

# %%
'nan' in good_names
# Out:
# True

# %%
len(good_names)
# Out:
# 7917

# %%
all([type(n) == str for n in good_names])
# Out:
# True

# %%
the_good_names = good_names

# %%
congress_names = pd.DataFrame({'name': good_names})

# %%
df.to_csv(out_file_path, sep="|", index=False)

# %%
out_file_path = "/home/rocassius/data/voteview/congress_names.csv"

# %%
congress_names.to_csv(out_file_path, sep = "|", index = False)

# %%
len(good_names)

# %%
name_stopwords = pd.read_csv(out_file_path).name.tolist()
#name_stopwords = pd.read_csv(os.path.join(DATA_PATH, "voteview/congress_names.csv")).name.tolist()

# %%
len(name_stopwords)
# Out:
# 7916

# %%
os.path.join(DATA_PATH, "voteview/congress_names.csv")

# %%
import os
import pandas as pd

# %%
name_stopwords = pd.read_csv(os.path.join(DATA_PATH, "voteview/congress_names.csv")).name.tolist()

# %%
np.argwhere(np.isnan(name_stopwords))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-324a9cb51b01> in <module>
# ----> 1 np.argwhere(np.isnan(name_stopwords))
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
stop_words

# %%
# manual stop words from Gentzkow et al.
manual_stopwords = ['absent','committee','gentlelady','hereabout','hereinafter','hereto','herewith' 'nay',
'pro','sir','thereabout','therebeforn','therein','theretofore','therewithal','whereat','whereinto','whereupon',
 'yea','adjourn','con','gentleman','hereafter','hereinbefore','heretofore','month','none','republican','speak',
 'thereafter','thereby','thereinafter','thereunder','today','whereby','whereof','wherever','yes','ask','democrat',
 'gentlemen','hereat','hereinto','hereunder','mr','now','say','speaker','thereagainst','therefor','thereof',
 'thereunto','whereabouts','wherefore','whereon','wherewith','yield','can','etc','gentlewoman','hereby','hereof',
 'hereunto','mrs','part','senator','tell','thereat','therefore','thereon','thereupon','whereafter','wherefrom',
 'whereto','wherewithal','chairman','gentleladies','gentlewomen','herein','hereon','hereupon','nai','per','shall',
 'thank','therebefore','therefrom','thereto','therewith','whereas','wherein','whereunder','will']

# list of US states
us_states_stopwords = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

us_states_stopwords = [state.lower() for state in us_states_stopwords]

unigram_stops = [y for x in [manual_stopwords, us_states_stopwords] for y in x]

# %%
unigram_stops

# %%
speeches.head()

# %%
total_speech = " ".join(speeches["speech"].values)

# %%
total_speech[:500]
